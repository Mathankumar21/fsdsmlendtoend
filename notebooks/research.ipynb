# %%
# data ingestion

# %%
import pandas as pd

# %%
# I have to Solve EDA step by step

# %%
data=pd.read_csv(r"D:\\Full_Stack_Data_Science\\fsdsmlendtoend\\notebooks\data\\gemstone.csv")

# %%
data.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
data.tail()
# Out:
#             id  carat        cut color clarity  depth  table     x     y  \
# 193568  193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39
# 193569  193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77
# 193570  193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75
# 193571  193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49
# 193572  193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71
#
#            z  price
# 193568  2.67   1130
# 193569  3.47   2874
# 193570  3.62   3036
# 193571  2.81    681
# 193572  3.48   2258

# %%
data.sample(5)
# Out:
#             id  carat      cut color clarity  depth  table     x     y     z  \
# 37281    37281   0.30    Ideal     G    VVS1   62.0   53.7  4.30  4.34  2.68
# 187119  187119   0.31    Ideal     D     VS1   61.5   56.0  4.37  4.40  2.70
# 146033  146033   1.20     Good     I     SI1   64.0   61.0  6.62  6.55  4.22
# 155389  155389   0.75  Premium     F     SI1   60.9   58.0  5.88  5.81  3.55
# 172648  172648   0.42    Ideal     G     VS1   61.9   55.0  4.82  4.85  2.99
#
#         price
# 37281     667
# 187119    914
# 146033   5654
# 155389   2749
# 172648    921

# %%
data.isnull().sum()
# Out:
# id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 11 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       193573 non-null  int64
#  1   carat    193573 non-null  float64
#  2   cut      193573 non-null  object
#  3   color    193573 non-null  object
#  4   clarity  193573 non-null  object
#  5   depth    193573 non-null  float64
#  6   table    193573 non-null  float64
#  7   x        193573 non-null  float64
#  8   y        193573 non-null  float64
#  9   z        193573 non-null  float64
#  10  price    193573 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 16.2+ MB

# %%
data = data.drop(labels=["id"], axis = 1)

# %%
data.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 193568    False
# 193569    False
# 193570    False
# 193571    False
# 193572    False
# Length: 193573, dtype: bool

# %%
data.shape
# Out:
# (193573, 10)

# %%
# categorical vs numerical

data.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# x          float64
# y          float64
# z          float64
# price        int64
# dtype: object

# %%
categorical_column = data.columns[data.dtypes=='object']

# %%
numerical_column = data.columns[data.dtypes!='object']

# %%
data[numerical_column]
# Out:
#         carat  depth  table     x     y     z  price
# 0        1.52   62.2   58.0  7.27  7.33  4.55  13619
# 1        2.03   62.0   58.0  8.06  8.12  5.05  13387
# 2        0.70   61.2   57.0  5.69  5.73  3.50   2772
# 3        0.32   61.6   56.0  4.38  4.41  2.71    666
# 4        1.70   62.6   59.0  7.65  7.61  4.77  14453
# ...       ...    ...    ...   ...   ...   ...    ...
# 193568   0.31   61.1   56.0  4.35  4.39  2.67   1130
# 193569   0.70   60.3   58.0  5.75  5.77  3.47   2874
# 193570   0.73   63.1   57.0  5.72  5.75  3.62   3036
# 193571   0.34   62.9   55.0  4.45  4.49  2.81    681
# 193572   0.71   60.8   64.0  5.73  5.71  3.48   2258
#
# [193573 rows x 7 columns]

# %%
data[categorical_column]
# Out:
#               cut color clarity
# 0         Premium     F     VS2
# 1       Very Good     J     SI2
# 2           Ideal     G     VS1
# 3           Ideal     G     VS1
# 4         Premium     G     VS2
# ...           ...   ...     ...
# 193568      Ideal     D    VVS2
# 193569    Premium     G    VVS2
# 193570  Very Good     F     SI1
# 193571  Very Good     D     SI1
# 193572       Good     E     SI2
#
# [193573 rows x 3 columns]

# %%
data[categorical_column].describe()
# Out:
#            cut   color clarity
# count   193573  193573  193573
# unique       5       7       8
# top      Ideal       G     SI1
# freq     92454   44391   53272

# %%
data[numerical_column].describe()
# Out:
#                carat          depth          table              x  \
# count  193573.000000  193573.000000  193573.000000  193573.000000
# mean        0.790688      61.820574      57.227675       5.715312
# std         0.462688       1.081704       1.918844       1.109422
# min         0.200000      52.100000      49.000000       0.000000
# 25%         0.400000      61.300000      56.000000       4.700000
# 50%         0.700000      61.900000      57.000000       5.700000
# 75%         1.030000      62.400000      58.000000       6.510000
# max         3.500000      71.600000      79.000000       9.650000
#
#                    y              z          price
# count  193573.000000  193573.000000  193573.000000
# mean        5.720094       3.534246    3969.155414
# std         1.102333       0.688922    4034.374138
# min         0.000000       0.000000     326.000000
# 25%         4.710000       2.900000     951.000000
# 50%         5.720000       3.530000    2401.000000
# ...

# %%
data[numerical_column].describe().T
# Out:
#           count         mean          std    min     25%      50%      75%  \
# carat  193573.0     0.790688     0.462688    0.2    0.40     0.70     1.03
# depth  193573.0    61.820574     1.081704   52.1   61.30    61.90    62.40
# table  193573.0    57.227675     1.918844   49.0   56.00    57.00    58.00
# x      193573.0     5.715312     1.109422    0.0    4.70     5.70     6.51
# y      193573.0     5.720094     1.102333    0.0    4.71     5.72     6.51
# z      193573.0     3.534246     0.688922    0.0    2.90     3.53     4.03
# price  193573.0  3969.155414  4034.374138  326.0  951.00  2401.00  5408.00
#
#             max
# carat      3.50
# depth     71.60
# table     79.00
# x          9.65
# y         10.01
# z         31.30
# price  18818.00

# %%
data[categorical_column].value_counts()
# Out:
# cut    color  clarity
# Ideal  E      VS2        5490
#        G      VS2        5131
#               VS1        5107
#        E      SI1        4309
#        F      VS2        4235
#                          ...
#        J      I1            2
# Fair   D      I1            2
#        F      IF            1
#        D      VVS1          1
# Good   J      IF            1
# Name: count, Length: 276, dtype: int64

# %% [markdown]
# ![f5f9e3bf1dfe64054161ede9d7be2242.jpg](attachment:f5f9e3bf1dfe64054161ede9d7be2242.jpg)

# %%
data[categorical_column]["cut"].value_counts()
# Out:
# cut
# Ideal        92454
# Premium      49910
# Very Good    37566
# Good         11622
# Fair          2021
# Name: count, dtype: int64

# %%
data[categorical_column]["color"].value_counts()
# Out:
# color
# G    44391
# E    35869
# F    34258
# H    30799
# D    24286
# I    17514
# J     6456
# Name: count, dtype: int64

# %%
data[categorical_column]["clarity"].value_counts()
# Out:
# clarity
# SI1     53272
# VS2     48027
# VS1     30669
# SI2     30484
# VVS2    15762
# VVS1    10628
# IF       4219
# I1        512
# Name: count, dtype: int64

# %%
data[numerical_column].describe().T
# Out:
#           count         mean          std    min     25%      50%      75%  \
# carat  193573.0     0.790688     0.462688    0.2    0.40     0.70     1.03
# depth  193573.0    61.820574     1.081704   52.1   61.30    61.90    62.40
# table  193573.0    57.227675     1.918844   49.0   56.00    57.00    58.00
# x      193573.0     5.715312     1.109422    0.0    4.70     5.70     6.51
# y      193573.0     5.720094     1.102333    0.0    4.71     5.72     6.51
# z      193573.0     3.534246     0.688922    0.0    2.90     3.53     4.03
# price  193573.0  3969.155414  4034.374138  326.0  951.00  2401.00  5408.00
#
#             max
# carat      3.50
# depth     71.60
# table     79.00
# x          9.65
# y         10.01
# z         31.30
# price  18818.00
